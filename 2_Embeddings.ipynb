# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaya200722/AGENTIC_AI/blob/main/2_Embeddings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sentence-transformers

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-c78c313d-4b70-45c9-a1a3-8cb667ff1d89" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c78c313d-4b70-45c9-a1a3-8cb667ff1d89">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sentence_transformers import SentenceTransformer

# ----------------------------
# Step 1: Read document
# ----------------------------

with open("ML.txt", "r", encoding="utf-8") as file:
    text = file.read()

# ----------------------------
# Step 2: Chunk the document
# ----------------------------

chunk_size = 100

chunks = []

for i in range(0, len(text), chunk_size):
    chunks.append(text[i:i + chunk_size])

print("=" * 60)
print("DOCUMENT CHUNKS")
print("=" * 60)

for i, chunk in enumerate(chunks):
    print(f"\nChunk {i + 1}")
    print(chunk)

# ----------------------------
# Step 3: Load embedding model
# ----------------------------

print("\nLoading embedding model...\n")

model = SentenceTransformer("all-MiniLM-L6-v2")

# ----------------------------
# Step 4: Create embeddings
# ----------------------------

embeddings = model.encode(chunks)

print("=" * 60)
print("EMBEDDINGS CREATED")
print("=" * 60)

print(f"\nNumber of chunks : {len(chunks)}")
print(f"Embedding dimension : {len(embeddings[0])}")

# Display first 10 values of each embedding

for i, emb in enumerate(embeddings):
    print(f"\nChunk {i + 1}")
    print(emb[:10])
# Out:
# ...
# DOCUMENT CHUNKS
# ...
#
# Chunk 1
# Machine Learning
#
# Machine Learning is a branch of Artificial Intelligence that enables computers to
#
# Chunk 2
# learn patterns from data without being explicitly programmed. It uses algorithms to analyze data and
#
# Chunk 3
#  make predictions or decisions.
#
# Types of Machine Learning
#
# There are three main types of machine le
#
# Chunk 4
# arning: supervised learning, unsupervised learning, and reinforcement learning.
#
# Supervised Learning
#
# Chunk 5
#
#
# In supervised learning, the model learns from labeled data. The input data is provided along with
#
# Chunk 6
# the correct output. The model learns the relationship between inputs and outputs and can then make p
#
# Chunk 7
# redictions on new data. Examples include classification and regression.
#
# Unsupervised Learning
#
# In u
#
# Chunk 8
# nsupervised learning, the model works with unlabeled data. It tries to discover hidden patterns or s
#
# Chunk 9
# ...
