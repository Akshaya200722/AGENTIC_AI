# %% [markdown]
# <a href="https://colab.research.google.com/github/Akshaya200722/AGENTIC_AI/blob/main/SemanticSearch(Query_No_LLM).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q sentence-transformers scikit-learn

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb8a6d9c-3392-46bb-a2d4-cff4e05860bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb8a6d9c-3392-46bb-a2d4-cff4e05860bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# ------------------------------------------------
# STEP 1 : Read document
# ------------------------------------------------

with open("ML.txt", "r", encoding="utf-8") as file:
    text = file.read()

print("Document loaded successfully!")
print("Number of characters:", len(text))
# Out:
# Document loaded successfully!
# Number of characters: 2310

# %%
# ------------------------------------------------
# STEP 2 : Chunking
# ------------------------------------------------

chunk_size = 100

chunks = []

for i in range(0, len(text), chunk_size):
    chunks.append(text[i:i + chunk_size])

print("\nNumber of chunks:", len(chunks))

# ------------------------------------------------
# STEP 3 : Load embedding model
# ------------------------------------------------

print("\nLoading embedding model...\n")

model = SentenceTransformer("all-MiniLM-L6-v2")

# ------------------------------------------------
# STEP 4 : Create chunk embeddings
# ------------------------------------------------

chunk_embeddings = model.encode(chunks)

print("Embeddings created successfully.")

# ------------------------------------------------
# STEP 5 : Ask Question
# ------------------------------------------------

question = input("\nEnter your question: ")

# ------------------------------------------------
# STEP 6 : Create question embedding
# ------------------------------------------------

question_embedding = model.encode([question])

# ------------------------------------------------
# STEP 7 : Calculate cosine similarity
# ------------------------------------------------

scores = cosine_similarity(
    question_embedding,
    chunk_embeddings
)

# ------------------------------------------------
# STEP 8 : Find best chunk
# ------------------------------------------------

best_index = np.argmax(scores)

print("\n==============================")
print("Most Relevant Chunk")
print("==============================\n")

print(chunks[best_index])

print("\nSimilarity Score:", scores[0][best_index])
# Out:
# Number of chunks: 24
#
# Loading embedding model...
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ...
